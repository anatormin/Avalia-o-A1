# %% [markdown]
# <a href="https://colab.research.google.com/github/anatormin/Avalia-o-A1/blob/main/Estruturas_Condicionais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Sistema de verificação de idade para entrada em eventos

# Entrada de dados
idade = int(input("Digite sua idade: "))

# Estrutura condicional
if idade < 0:
    print("Idade inválida.")
elif idade < 16:
    print("Entrada não permitida.")
elif 16 <= idade < 18:
    print("Entrada permitida somente acompanhado de responsável.")
else:
    print("Entrada liberada.")
